# %% [markdown]
# ### Simple Challenge 4
#
# In pandas library, you can read CSV data file using the ```read_csv``` function in pandas. The function will read the csv data file straight into data frame, with the default setting where 1st row of the data file will become the header of the data frame.

# %%
import pandas as pd

data = pd.read_csv('telco-customer-churn.csv')
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# TASK 1
cond1 = data['tenure'] >12
cond2 = data['SeniorCitizen'] == 1

task1 = data[cond1&cond2]
task1.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 30  3841-NFECX  Female              1     Yes         No      71          Yes
# 50  8012-SOUDQ  Female              1      No         No      43          Yes
# 52  6575-SUVOI  Female              1     Yes         No      25          Yes
# 54  4667-QONEA  Female              1     Yes        Yes      60          Yes
# 55  1658-BYGOY    Male              1      No         No      18          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 30           Yes     Fiber optic            Yes  ...              Yes
# 50           Yes     Fiber optic             No  ...               No
# 52           Yes             DSL            Yes  ...               No
# 54            No             DSL            Yes  ...              Yes
# 55           Yes     Fiber optic             No  ...               No
#
# ...

# %%
# TASK 2
churn = data[data.Churn == 'Yes']
minimum = churn['tenure'].min()
maximum = churn['tenure'].max()
amount = churn['tenure'].count()
average = churn['tenure'].mean()
print(minimum)
print(maximum)
print(amount)
print(round(average,2))
# Out:
# 1
# 72
# 1869
# 17.98

# %%
# TASK 3
task3 = pd.DataFrame(data,columns=['customerID', 'Churn', 'InternetService', 'StreamingTV','tenure','Contract','MonthlyCharges']) 
newdf = task3[task3['tenure'] >12]

sort_df = newdf.sort_values(["tenure", "MonthlyCharges"], ascending = (True, False))
sort_df
# Out:
#       customerID Churn InternetService          StreamingTV  tenure  \
# 261   3606-TWKGI   Yes     Fiber optic                  Yes      13
# 6193  5716-LIBJC    No     Fiber optic                  Yes      13
# 6125  0871-URUWO   Yes     Fiber optic                  Yes      13
# 2708  8510-AWCXC   Yes     Fiber optic                  Yes      13
# 6714  7315-WYOAW    No     Fiber optic                  Yes      13
# ...          ...   ...             ...                  ...     ...
# 4201  1166-PQLGG    No              No  No internet service      72
# 109   2848-YXSMW    No              No  No internet service      72
# 1329  3910-MRQOY    No              No  No internet service      72
# 932   5787-KXGIY    No              No  No internet service      72
# 2693  3976-HXHCE    No              No  No internet service      72
#
#             Contract  MonthlyCharges
# 261   Month-to-month          106.90
# 6193        One year          104.15
# ...
