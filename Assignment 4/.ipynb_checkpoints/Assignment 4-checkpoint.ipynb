# %% [markdown]
# ASSIGNMENT 3
#
# Topic: Data Aggregation & Visualization

# %% [markdown]
# TASK 1:
#
# (a)	Load Sales Data.csv, assign it into variable named sales.
#
# Display the first 10 rows of the sales.

# %%
import pandas as pd
sales = pd.read_csv('Sales Data.csv')
sales.head(10)
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
# 5             6       2760      1555        4890         7490     1890
# 6             7       2980      1120        4780         8980     1780
# 7             8       3700      1400        5860         9960     2860
# 8             9       3540      1780        6100         8100     2100
# 9            10       1990      1890        8300        10300     2300
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600
# 5         1555        20140        201400
# 6         1120        29550        295500
# 7         1400        36140        361400
# 8         1780        23400        234000
# 9         1890        26670        266700

# %% [markdown]
# (b)	Get total profit of all months and show line plot with the following style properties:
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt

x = sales.month_number
y = sales.total_profit

plt.figure()
plt.plot(x, y, 'r:', lw=3, marker='o', markersize=8, markerfacecolor="blue")  
plt.xlabel('Month Number')
plt.ylabel('Sold Unit number')
plt.title('Company Sales per Month')
plt.legend(['Sales'],loc=4)
plt.show()

# %% [markdown]
# (c)	Read data from Sales Data.csv and show all product sales using a multiline plot, sized 1200 × 600 pixels. Differentiate all the lines by line color and marker.

# %%
y1 = sales['facecream']
y2 = sales['facewash']
y3 = sales['toothpaste']
y4 = sales['bathingsoap']
y5 = sales['shampoo']
y6 = sales['moisturizer']

# %%
fig, ax = plt.subplots(figsize=(12,6), dpi=100)

ax.plot(x, y1, 'r-', lw=3, marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, y2, 'g-', lw=3, marker='o', markersize=8, markerfacecolor="green")
ax.plot(x, y3, 'k-', lw=3, marker='o', markersize=8, markerfacecolor="black")
ax.plot(x, y4, 'c-', lw=3, marker='o', markersize=8, markerfacecolor="cyan")
ax.plot(x, y5, 'b-', lw=3, marker='o', markersize=8, markerfacecolor="blue")
ax.plot(x, y6, 'm-', lw=3, marker='o', markersize=8, markerfacecolor="purple")

plt.xlabel('Month Number')
plt.ylabel('Product sales')
plt.title('Product Sales Per Month')
plt.legend(['facecream', 'facewash','toothpaste','bathingsoap','shampoo','moisturizer'])
plt.show()

# %% [markdown]
# (d)	The products in the sales data can be further grouped as follow:
#
#     a.	Category A: facecream, facewash, moisturizer
#     b.	Category B: toothpaste
#     c.	Category C: bathingsoap, shampoo
#
# Group the data accordingly and obtain the following information, then plot into two subplots:
#     1.	total profit of each category for every month
#     2.	percentage of each category for every month over the grand total profit of all categories.

# %%
cat_a = pd.pivot_table(sales, values=['facecream','facewash','moisturizer'], index='month_number') 
cat_b = pd.pivot_table(sales, values=['toothpaste'], index='month_number')
cat_c = pd.pivot_table(sales, values=['bathingsoap','shampoo'], index='month_number')

# %%
cat_a['total_profit by month'] = cat_a.sum(axis=1)*10
cat_b['total_profit by month'] = cat_b.sum(axis=1)*10
cat_c['total_profit by month'] = cat_c.sum(axis=1)*10

cat_a['Percentage_A']=(cat_a['total_profit by month']/sales['total_profit'])*100
cat_b['Percentage_B']=(cat_b['total_profit by month']/sales['total_profit'])*100
cat_c['Percentage_C']=(cat_c['total_profit by month']/sales['total_profit'])*100

# %%
print(cat_a)
print(cat_b)
print(cat_c)
# Out:
#               facecream  facewash  moisturizer  total_profit by month  \
# month_number
# 1                  2500      1500         1500                  55000
# 2                  2630      1200         1200                  50300
# 3                  2140      1340         1340                  48200
# 4                  3400      1130         1130                  56600
# 5                  3600      1740         1740                  70800
# 6                  2760      1555         1555                  58700
# 7                  2980      1120         1120                  52200
# 8                  3700      1400         1400                  65000
# 9                  3540      1780         1780                  71000
# 10                 1990      1890         1890                  57700
# 11                 2340      2100         2100                  65400
# 12                 2900      1760         1760                  64200
#
#               Percentage_A
# month_number
# 1                30.005456
# 2                22.385403
# 3                21.643467
# 4                27.003817
# 5                35.153923
# 6                19.864636
# 7                14.443830
# 8                27.777778
# 9                26.621672
# 10               13.977713
# 11               21.785476
# 12                     NaN
#               toothpaste  total_profit by month  Percentage_B
# month_number
# 1                   5200                  52000     28.368794
# 2                   5100                  51000     22.696929
# 3                   4550                  45500     20.431073
# 4                   5870                  58700     28.005725
# 5                   4560                  45600     22.641509
# 6                   4890                  48900     16.548223
# 7                   4780                  47800     13.226342
# 8                   5860                  58600     25.042735
# 9                   6100                  61000     22.872141
# 10                  8300                  83000     20.106589
# 11                  7300                  73000     24.317122
# 12                  7400                  74000           NaN
#               bathingsoap  shampoo  total_profit by month  Percentage_C
# month_number
# 1                    9200     1200                 104000     56.737589
# 2                    6100     2100                  82000     36.493102
# 3                    9550     3550                 131000     58.823529
# 4                    8870     1870                 107400     51.240458
# 5                    7760     1560                  93200     46.276068
# 6                    7490     1890                  93800     31.742809
# 7                    8980     1780                 107600     29.773105
# 8                    9960     2860                 128200     54.786325
# 9                    8100     2100                 102000     38.245219
# 10                  10300     2300                 126000     30.523256
# 11                  13300     2400                 157000     52.298468
# 12                  14400     1800                 162000           NaN

# %%
fig, ax = plt.subplots(2, 1, figsize=(12, 6),dpi=100)

ax[0].plot(x, cat_a['total_profit by month'],'r*-',lw=3,marker='o', markersize=8, markerfacecolor="red")
ax[0].plot(x, cat_b['total_profit by month'],'b*-',lw=3,marker='o', markersize=8, markerfacecolor="blue")
ax[0].plot(x, cat_c['total_profit by month'],'y*-',lw=3,marker='o', markersize=8, markerfacecolor="yellow")
ax[1].plot(x, cat_a['Percentage_A'],'r*-',lw=3,marker='o', markersize=8, markerfacecolor="red") 
ax[1].plot(x, cat_b['Percentage_B'],'b*-',lw=3,marker='o', markersize=8, markerfacecolor="blue")
ax[1].plot(x, cat_c['Percentage_C'],'y*-',lw=3,marker='o', markersize=8, markerfacecolor="yellow")

ax[1].legend(['Category A', 'Category B','Category C'],loc='upper center', 
             bbox_to_anchor=(0.5, -0.2),fancybox=False, shadow=False, ncol=3)
ax[1].set_xlabel('Month')
ax[0].set_ylabel('Total Profit of Each Month')
ax[1].set_ylabel('Percentage over Total Profit')
fig.suptitle('Category subplots')
plt.show()
