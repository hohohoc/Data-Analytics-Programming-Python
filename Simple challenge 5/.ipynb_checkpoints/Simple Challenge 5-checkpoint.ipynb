# %%
import pandas as pd
df_telco = pd.read_csv('telco-customer-churn.csv')
df_telco.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
def difference(data):
    return data.max() - data.min()

q1 = df_telco.groupby(['InternetService','gender'])
q1['MonthlyCharges'].agg([('minimum','min'),('maximum','max'),('average','mean'),('difference (max-min)',difference)])
# Out:
#                         minimum  maximum    average  difference (max-min)
# InternetService gender
# DSL             Female    23.90    94.80  58.590741                 70.90
#                 Male      23.45    92.30  57.631427                 68.85
# Fiber optic     Female    68.65   118.75  91.472569                 50.10
#                 Male      67.75   118.35  91.527868                 50.60
# No              Female    18.40    26.90  21.110710                  8.50
#                 Male      18.25    26.45  21.048973                  8.20

# %%
df_telco.groupby(['SeniorCitizen','OnlineSecurity']).size()
# Out:
# SeniorCitizen  OnlineSecurity
# 0              No                     2690
#                No internet service    1474
#                Yes                    1737
# 1              No                      808
#                No internet service      52
#                Yes                     282
# dtype: int64

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
q3 = df_telco.groupby(['Churn','InternetService'])
q3['tenure'].agg([('Average','mean'),('Max-Min',difference)])
# Out:
#                          Average  Max-Min
# Churn InternetService
# No    DSL              37.198777       72
#       Fiber optic      42.089494       71
#       No               32.331210       72
# Yes   DSL              14.111111       71
#       Fiber optic      20.196608       71
#       No                8.238938       60

# %% [markdown]
# ![image.png](attachment:image.png)
